# %% [markdown]
# ## Análise sobre despesas de campanhas de candidatos em Caçapava (Eleições 2020)

# %% [markdown]
# #### Faculdade: FATEC Jessen Vidal de São José dos Campos
#
# #### Aluno: Jefferson de Moura

# %% [markdown]
# import pandas as pd
# import seaborn as sb
# import matplotlib.pyplot as plt
# import numpy as np
# %matplotlib inline
# plt.style.use('fivethirtyeight')
# pd.options.display.max_columns = 80
# pd.options.display.max_rows = 90

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use('fivethirtyeight')
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
path = 'datasets/'
name = 'despesas_contratadas_candidatos_2020'
extension = '.xlsx'

# %%
df = pd.read_excel(path+name+extension)

# %% [markdown]
# ## 1 - Número de despesas contratadas por municipio no estado de São Paulo

# %%
df.groupby('NM_UE').size().sort_values().tail(10).plot(kind='barh', figsize=(10,6))
# Out:
# <AxesSubplot:ylabel='NM_UE'>

# %% [markdown]
# ## 2 - Proporção de registros separado por tipo de candidatos

# %%
df.groupby('DS_CARGO').size().sort_values().tail().plot(kind='pie',title = 'Cargo', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Cargo'}, ylabel='None'>

# %% [markdown]
# ## 3 - Número de despesas contratadas por partido no estado de São Paulo

# %%
df.groupby('NM_PARTIDO').size().sort_values().tail(10).plot(kind='barh', title = 'Partido SP', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Partido SP'}, ylabel='NM_PARTIDO'>

# %% [markdown]
# ## 4 - Número de despesas por candidato no estado de São Paulo

# %%
df.groupby('NM_CANDIDATO').size().sort_values().tail(10).plot(kind='barh', title = 'Candidato SP', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Candidato SP'}, ylabel='NM_CANDIDATO'>

# %% [markdown]
# ## 5 - Número de despesas por partidos em Caçapava

# %%
df.query('NM_UE == "CAÇAPAVA"').groupby('NM_PARTIDO').size().sort_values().tail(10).plot(kind='barh', title = 'Partidos em Caçapava', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Partidos em Caçapava'}, ylabel='NM_PARTIDO'>

# %% [markdown]
# ## 6 - Número de despesas por candidatos em Caçapava

# %%
df.query('NM_UE == "CAÇAPAVA"').groupby('NM_CANDIDATO').size().sort_values().tail(10).plot(kind='barh', title = 'Candidatos em Caçapava', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Candidatos em Caçapava'}, ylabel='NM_CANDIDATO'>

# %%
df.query('NM_UE == "CAÇAPAVA"').groupby(['NM_CANDIDATO']).size().sort_values().tail(10).plot(kind='barh', title = 'Candidatos em Caçapava', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Candidatos em Caçapava'}, ylabel='NM_CANDIDATO'>
